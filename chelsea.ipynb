# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage

# %%
from skimage import data

# %%
coffee_image = data.coffee()
coins_image = data.coins()

# %%
coffee_image.shape
# Out:
# (400, 600, 3)

# %%
coins_image.shape
# Out:
# (303, 384)

# %%
from skimage import data , color

# %%
from skimage.color import rgb2gray

# %%
chelsea = data.chelsea()

# %%
gray_chelsea = color.rgb2gray(chelsea)

# %%
plt.imshow(chelsea)

# %%
plt.imshow(gray_chelsea)

# %%
type(gray_chelsea)
# Out:
# numpy.ndarray

# %%
gray_chelsea.shape
# Out:
# (300, 451)

# %%
hor_flp_chelsea = np.fliplr(chelsea)

# %%
plt.imshow(hor_flp_chelsea)

# %%
def image_show(image, nrows=1, ncols=1, cmap='gray'):
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols)
    ax.imshow(image, cmap='gray')
    ax.axis('off')
    return fig, ax

# %%
image_show(chelsea)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x6250baa50>)

# %%
image_show(gray_chelsea)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x62511d450>)

# %%
red_channel = chelsea[:,:,0]
plt.hist(red_channel.ravel(), bins=256)
plt.title('Red Histogram')
plt.show()
